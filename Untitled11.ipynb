# %%
import pandas as pd
import librosa
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tensorflow as tf
import librosa.display
import cv2
import os
from pathlib import Path
# Out:
# C:\Users\salim\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
data = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

# %%
data.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
w = data['class'].unique()
z = data['class'].value_counts(ascending=True)
plt.figure(figsize=(5,5))
plt.bar(w,z)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Column Names
#
# *slice_file_name: The name of the audio file. The name takes the following format: [fsID]-[classID]-[occurrenceID]-[sliceID].wav, where: [fsID] = the Freesound ID of the recording from which this excerpt (slice) is taken [classID] = a numeric identifier of the sound class (see description of classID below for further details) [occurrenceID] = a numeric identifier to distinguish different occurrences of the sound within the original recording [sliceID] = a numeric identifier to distinguish different slices taken from the same occurrence
#
# *fsID: The Freesound ID of the recording from which this excerpt (slice) is taken
#
# *start The start time of the slice in the original Freesound recording
#
# *end: The end time of slice in the original Freesound recording
#
# *salience: A (subjective) salience rating of the sound. 1 = foreground, 2 = background.
#
# *fold: The fold number (1-10) to which this file has been allocated.
#
# *classID: A numeric identifier of the sound class: 0 = air_conditioner 1 = car_horn 2 = children_playing 3 = dog_bark 4 = drilling 5 = engine_idling 6 = gun_shot 7 = jackhammer 8 = siren 9 = street_music
#
# *class: The class name: air_conditioner, car_horn, children_playing, dog_bark, drilling, engine_idling, gun_shot, jackhammer, siren, street_music.

# %%
y1,samp_rate1 = librosa.load('UrbanSound8K/audio/fold5/100032-3-0-0.wav')
y2,samp_rate2 = librosa.load('UrbanSound8K/audio/fold5/100263-2-0-117.wav')
#loads and decodes the audio as a time series 'y', represented as a one-dimensional NumPy floating point array.
#The variable samp_rate contains the sampling rate of y, that is, the number of samples per second of audio. (hertz)

# %%
y1 # array
# Out:
# array([-0.00341243, -0.00506065, -0.00463294, ..., -0.00247565,
#        -0.00155365, -0.00035246], dtype=float32)

# %%
samp_rate1 # Hz
# Out:
# 22050

# %%
plt.figure(figsize=(8,12))
Y = librosa.amplitude_to_db(np.abs(librosa.stft(y1)), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(Y, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.show()

# %%
arr = np.array(data['slice_file_name'])
fold = np.array(data['fold'])
cla = np.array(data['class'])

for i in range(55,56,1):
    
    path = 'UrbanSound8K/audio/fold' + str(fold[i]) + '/' + arr[i]
    dataNew, sampling_rateNew = librosa.load(path)
    
    plt.figure(figsize=(8,12))
    Y = librosa.amplitude_to_db(np.abs(librosa.stft(dataNew)), ref=np.max)
    plt.subplot(4, 2, 1)
    librosa.display.specshow(Y, y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title(cla[i])
    plt.show()

# %%
def create_spectrogram(y):
    spec = librosa.feature.melspectrogram(y=y)
    spec_conv = librosa.amplitude_to_db(spec, ref=np.max)
    return spec_conv

# %%
data.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
#spectrogram oluşturma
"""arr = np.array(data['slice_file_name'])
fold = np.array(data['fold'])
cla = np.array(data['class'])

for i in range(8732):
    
    path = 'UrbanSound8K/audio/fold' + str(fold[i]) + '/' + arr[i]
    d, sr = librosa.load(path)
    plt.figure(frameon=False)
    plt.subplot(1,1,1)
    librosa.display.specshow(create_spectrogram(d))
    plt.savefig('classes/'+cla[i]+'/'+arr[i][:-3]+'png')"""
# Out:
# "arr = np.array(data['slice_file_name'])\nfold = np.array(data['fold'])\ncla = np.array(data['class'])\n\nfor i in range(8732):\n    \n    path = 'UrbanSound8K/audio/fold' + str(fold[i]) + '/' + arr[i]\n    d, sr = librosa.load(path)\n    plt.figure(frameon=False)\n    plt.subplot(1,1,1)\n    librosa.display.specshow(create_spectrogram(d))\n    plt.savefig('classes/'+cla[i]+'/'+arr[i][:-3]+'png')"

# %%
data.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
def pre_proc(img_path):

    img = cv2.imread(img_path)
    gray_scale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    new_width = 480
    new_height = 480
    dsize_h = (new_width, img.shape[0])
    dsize_v = (img.shape[1], new_height)

    new_img = cv2.resize(gray_scale_image, dsize_h, interpolation=cv2.INTER_AREA)
    new_img = cv2.resize(gray_scale_image, dsize_v, interpolation=cv2.INTER_AREA)

    return new_img

# %%
data_list=[]
for classes in os.listdir('classes'): # class dosyaları
    
    for img in os.listdir('classes'+'/'+classes): #dosyalardaki img'lar
        
        path = 'classes/'+classes+'/'+img
        temp_list = [pre_proc(path), img, classes]
        data_list.append(temp_list)

# %%
df = pd.DataFrame(data_list)

# %%
df.set_axis(['Array','Image Name','Class'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                Array         Image Name  \
# 0  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...   100852-0-0-0.png
# 1  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...   100852-0-0-1.png
# 2  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...  100852-0-0-10.png
# 3  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...  100852-0-0-11.png
# 4  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...  100852-0-0-12.png
#
#              Class
# 0  air_conditioner
# 1  air_conditioner
# 2  air_conditioner
# 3  air_conditioner
# 4  air_conditioner

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['Array'].tolist())
y = np.array(df['Class'].tolist())

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=15)

# %%
X_train.shape
# Out:
# (6985, 480, 640)

# %%
6985-1747
# Out:
# 5238

# %%
X_val = X_train[5238:]
y_val = y_train[5238:]
X_train = X_train[:5238]
y_train = y_train[:5238]

# %%
# Print the lengths of the each dataset
print(f"X_train: {len(X_train)} ")
print(f"X_test: {len(X_test)} ")
print(f"X_val: {len(X_val)} ")
# Out:
# X_train: 5238
# X_test: 1747
# X_val: 1747

# %%
X_train = X_train/255
X_test = X_test/255
X_val = X_val/255

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Conv2D,MaxPooling2D,Flatten

# %%
model = Sequential()

# %%
X_test.shape
# Out:
# (1747, 480, 640)

# %%
model.add(Conv2D(32,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                activation='relu',
                input_shape=(480, 640,3)))
model.add(MaxPooling2D(2,2))

# %%
model.add(Conv2D(64,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                activation='relu'))
model.add(MaxPooling2D(2,2))

# %%
model.add(Flatten())

# %%
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

# %%
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
results = model.fit(X_train,y_train,
                   epochs=50,
                   validation_data=(X_val,y_val),batch_size=128
                   )
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 480, 640, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 480, 640, 3), dtype=tf.float32, name='conv2d_3_input'), name='conv2d_3_input', description="created by layer 'conv2d_3_input'"), but it was called on an input with incompatible shape (None, 480, 640).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 results = model.fit(X_train,y_train,
#       2                    epochs=50,
#       3                    validation_data=(X_val,y_val),batch_size=128
#       4                    )
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filedwoeee9o.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\engine\training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\engine\training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\engine\training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\engine\training.py", line 889, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\salim\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 228, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "sequential_1" (type Sequential).
#
#     Input 0 of layer "conv2d_3" is incompatible with the layer: expected min_ndim=4, found ndim=3. Full shape received: (None, 480, 640)
#
#     Call arguments received by layer "sequential_1" (type Sequential):
#       • inputs=tf.Tensor(shape=(None, 480, 640), dtype=float32)
#       • training=True
#       • mask=None
